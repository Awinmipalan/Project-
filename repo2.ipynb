# %%
import pandas as pd

# %%
import numpy as np

# %%
raw_data=pd.read_csv('C:\\Users\\DELL\\Videos\\virus data set\\interstellar_travel.csv')

# %%
df=raw_data.copy()

# %%
df.describe()

# %%
display(df)

# %%
df.info()

# %%
df['Travel Class'].unique()

# %%
len(df['Travel Class'].unique())

# %%
sorted(df['Travel Class'].unique())

# %%
reason_columns = pd.get_dummies(df['Travel Class'])

# %%
reason_columns

# %%
reason_columns['check']=reason_columns.sum(axis=1)
reason_columns

# %%
reason_columns['check'].sum(axis=0)

# %%
reason_columns['check'].unique()

# %%
reason_columns = pd.get_dummies(df['Travel Class'],drop_first=True)
reason_columns

# %%
df.columns.values

# %%
df=df.drop(['Travel Class'],axis=1)

# %%
df

# %%
df['Economy']=reason_columns['Economy']

# %%
df['Luxury']=reason_columns['Luxury']

# %%
df

# %%
reason = pd.get_dummies(df['Purpose of Travel'])

# %%
reason

# %%
reason['check']=reason_columns.sum(axis=1)
reason

# %%
reason['check'].sum(axis=0)

# %%
reason['check'].unique()

# %%
reason = pd.get_dummies(df['Purpose of Travel'],drop_first=True)
reason

# %%
df=df.drop(['Purpose of Travel'],axis=1)

# %%
df

# %%
df['Colonization']=reason['Colonization']

# %%
df['Tourism']=reason['Tourism']

# %%
df['Other']=reason['Other']

# %%
df['Research']=reason['Research']

# %%
df

# %%
loyalty = pd.get_dummies(df['Loyalty Program Member'])

# %%
loyalty

# %%
loyalty['check']=reason_columns.sum(axis=1)
loyalty

# %%
gender = pd.get_dummies(df['Gender'])

# %%
gender

# %%
gender['check']=reason_columns.sum(axis=1)
gender

# %%
gender['check'].sum(axis=0)

# %%
loyalty['check'].sum(axis=0)

# %%
loyalty= pd.get_dummies(df['Loyalty Program Member'],drop_first=True)
loyalty

# %%
loyalty= pd.get_dummies(df['Loyalty Program Member'],drop_first=True)
loyalty

# %%
gender= pd.get_dummies(df['Gender'],drop_first=True)
gender

# %%
df=df.drop(['Loyalty Program Member'],axis=1)

# %%
df

# %%
df=df.drop(['Gender'],axis=1)

# %%
df

# %%
df['Gender']=gender

# %%
df

# %%
df['Loyalty Program Member']=loyalty

# %%
df

# %%
occupationp = pd.get_dummies(df['Occupation'])

# %%
occupationp

# %%
occupationp['check']=reason_columns.sum(axis=1)
occupationp

# %%
occupationp['check'].unique()

# %%
occupationp['check'].sum(axis=0)

# %%
occupationp= pd.get_dummies(df['Occupation'],drop_first=True)
occupationp

# %%
df=df.drop(['Occupation'],axis=1)

# %%
df

# %%
df['Colonist']=occupationp['Colonist']

# %%
df['Tourist']=occupationp['Tourist']

# %%
df['Other']=occupationp['Other']

# %%
df['Explorer']=occupationp['Explorer']

# %%
df['Scientist']=occupationp['Scientist']

# %%
df

# %%
df=df.drop(['Destination'],axis=1)

# %%
df

# %%
df=df.drop(['Star System'],axis=1)

# %%
df

# %%
dp=df.copy()

# %%
dp

# %%
request = pd.get_dummies(dp['Special Requests'],drop_first=True)
request

# %%
request['check']=reason_columns.sum(axis=1)
request

# %%
request['check'].sum(axis=0)

# %%
request['check'].unique()

# %%
dp=dp.drop(['Special Requests'],axis=1)

# %%
dp

# %%
dp['Other']=request['Other']
dp['Special Meal']=request['Special Meal']
dp['Window Seat']=request['Window Seat']

# %%
dp

# %%
dp.rename(columns={'Month':'Booking month'},inplace=True)

# %%
dp

# %%
dm=dp.copy()

# %%
type(dm['Departure Date'])

# %%
type(dm['Departure Date'][0])

# %%
type(dm['Booking Date'])

# %%
type(dm['Booking Date'][0])

# %%
dm['Booking Date']=pd.to_datetime(dm['Booking Date'])

# %%
dm['Booking Date'][0]

# %%
dm['Departure Date']=pd.to_datetime(dm['Departure Date'])

# %%
dm['Departure Date'][0]

# %%
dm['Departure Date'][0].month

# %%
dm['Departure month']=dm['Departure Date'].dt.month

# %%
dm

# %%
dm['Departure day']=dm['Departure Date'].dt.day

# %%
dm['Booking day']=dm['Booking Date'].dt.day

# %%
dm

# %%
dm=dm.drop(['Transportation Type'],axis=1)

# %%
dm

# %%
dl=dm.copy()

# %%
dl.rename(columns={'Special_Meal':'Special Meal'},inplace=True)

# %%
dll=pd.DataFrame(dl)

# %%
dll.columns.values

# %%
dll.columns.values

# %%
dll=dll.rename(columns=column_mapping)

# %%
import pymysql

# %%
conn=pymysql.connect(database='flight_service',user='root',password='09029909583')

# %%
cursor=conn.cursor()

# %%
cursor.execute('SELECT * FROM flights;')

# %%
insert_query = 'INSERT INTO flights VALUES'

# %%
insert_query

# %%
dll.shape

# %%
dll.columns.values,

# %%
dm['Age']

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
connection=pymysql.connect(host='localhost',
                           user='root',
                           password='09029909583',
                           database='flight_service')
dq=pd.DataFrame(dll,columns=['age', 'Distance_to_destination_light_years','duration_of_stay_earth_days', 'Number_0f_companion','Price_Galactic_Credit', 'Booking_date', 'Departure_date','Booking_month', 'Customer_Satisfaction_Score', 'Economy','Luxury', 'Colonization', 'Tourism', 'Other', 'Research', 'Gender','Loyalty_program__Member', 'colonist', 'Tourist', 'Explorer','Scientist', 'Special_Meal', 'Window_Seat', 'Departure_month','Departure_day', 'Booking_day'])
insert_query = "INSERT INTO flights( age,Distance_to_destination_light_years,duration_of_stay_earth_days,Number_0f_companion,Price_Galactic_Credit,Booking_date,Departure_date,Booking_month,Customer_Satisfaction_Score,Economy,Luxury,Colonization,Tourism,Other,Research,Gender,Loyalty_program__Member,colonist,Tourist,Scientist,Explorer,Special_Meal,Window_Seat,Departure_month,Departure_day,Booking_day,) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
engine = create_engine('mysql+pymysql://root:09029909583@localhost/flight_service')
dq.to_sql(name='flights',con=engine, if_exists='append',index=False)
connection.close()
